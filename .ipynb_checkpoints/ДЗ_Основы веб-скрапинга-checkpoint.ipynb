# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def habr_search(*queries):
    url = 'https://habr.com/ru/search/'
    all_results = []
    
    for query in queries:
        params = {'q': query}
        response = requests.get(url, params=params)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article', class_ = 'tm-articles-list__item')
        
        for article in articles:
            # Извлекаем дату
            time_tag = article.find('time')
            if time_tag:
                date = time_tag['title']
            else:
                date = 'Нет времени'
            # Извлекаем заголок    
            title_tag = article.find('a', class_ = 'tm-title__link')
            
            if title_tag:
                title = title_tag.find('span').get_text()
                # Извлекаем полную ссылку на статью
                link = 'https://habr.com' + title_tag['href']
            else:
                continue  # Пропускаем статью, если заголовок не найден

            # Добавляем результат в список
            all_results.append((date, title, link))
    
    
    unique_results = list(set(all_results))
    
    # Преобразуем в DataFrame
    df = pd.DataFrame(unique_results, columns=['Дата', 'Заголовок', 'Ссылка'])
    
    return df

# %%
df_habr = habr_search('python', 'анализ данных')

# %%
df_habr = df_habr.sort_values(by='Дата', ascending=False)

# %%
df_habr
# Out:
#                  Дата                                          Заголовок  \
# 17  2024-09-17, 16:00  ИТМО провёл исследование open source в сферах ...
# 22  2024-09-02, 10:27  55% Python-разработчиков используют Linux-окру...
# 29  2024-08-14, 16:20  IBM анонсировала бесплатные курсы в области ан...
# 32  2024-07-11, 09:57  Инсайдерам Microsoft 365 станет доступен редак...
# 38  2024-07-01, 14:46  Релиз открытой библиотеки для быстрой обработк...
# 24  2024-05-09, 07:43  Вышла первая бета-версия языка программировани...
# 6   2024-04-27, 10:20  Начните учиться бесплатно на курсе «Python для...
# 2   2023-11-09, 14:05  Alchemer совместно с JetBrains и Python Softwa...
# 21  2023-10-20, 07:17  Автор курсов по Python и Pandas жалуется на ве...
# 34  2023-10-09, 15:23  Три уровня погружения в Python. Запись докладо...
# 14  2023-10-09, 08:39  JetBrains и Python Software Foundation рассказ...
# 18  2023-09-26, 19:13  В России начался отбор на национальную школьну...
# 4   2023-09-19, 07:42  Microsoft представила дополнение Python Editor...
# 36  2023-08-22, 20:14                  Microsoft добавила Python в Excel
# 15  2023-06-14, 12:18  Новая библиотека для анализа данных Pandas AI:...
# 20  2023-05-29, 15:05  Оценка эффективности процесса найма с помощью ...
# 9   2023-03-21, 16:35  Moscow Python Meetup x YADRO: встречаемся 23 м...
# 13  2023-03-01, 10:28            Все про Школу анализа данных от Яндекса
# 37  2023-01-25, 11:56  СК проверит контракт на поставку МВД системы д...
# 1   2022-10-26, 15:32  Как понять, что пришло время внедрять платформ...
# 31  2022-10-25, 12:02                                  Вышел Python 3.11
# 28  2022-10-04, 17:23  Factory5 представила бесплатный сервис по анал...
# 39  2022-08-18, 16:37  Вебинар «От идеи до внедрения. Как построить с...
# 11  2022-06-21, 16:31  Яндекс Практикум запускает программу по матема...
# 33  2022-03-08, 12:13  Вышел мартовский релиз расширения Python для V...
# 16  2022-01-20, 18:37  Курс «Python для инженеров». Старт 3 потока 31...
# 12  2022-01-13, 18:35  Открытый урок «Пишем Custom Prometheus Exporte...
# 35  2021-12-13, 09:00  Жаждущим автоматизации: открытый урок «ChatOps...
# 3   2021-11-16, 16:09  EPAM разработала бесплатный курс по программир...
# 19  2021-07-06, 13:29  Python Community Meetup 8/07: видео и материал...
# 25  2020-12-04, 21:03  Python как компилируемый статически типизирова...
# 10  2020-04-21, 18:35  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 5   2020-04-17, 14:38  В Яндекс.Облаке открыт доступ к анализу данных...
# 30  2020-02-29, 20:23  Введение в архитектурный фреймворк для анализа...
# 8   2017-07-25, 13:47                10 лет Школе анализа данных Яндекса
# 26  2015-11-11, 08:39  Как мы учим машинному обучению и анализу данны...
# 23  2015-08-04, 14:09  В чем разница между наукой о данных, анализом ...
# 0   2014-04-24, 18:40  Новый набор в Школу анализа данных Яндекса и р...
# 7   2013-04-30, 13:17  Открылся новый набор в Школу анализа данных Ян...
# 27  2011-06-16, 21:18      Школа анализа данных Яндекса: снова выпускной
#
#                                                Ссылка
# 17                   https://habr.com/ru/news/844072/
# 22                   https://habr.com/ru/news/840224/
# 29                   https://habr.com/ru/news/836040/
# 32                   https://habr.com/ru/news/828098/
# 38                   https://habr.com/ru/news/825868/
# 24                   https://habr.com/ru/news/813271/
# 6   https://habr.com/ru/companies/yandex_praktikum...
# 2                    https://habr.com/ru/news/772872/
# 21                   https://habr.com/ru/news/768702/
# 34  https://habr.com/ru/companies/selectel/news/76...
# 14                   https://habr.com/ru/news/766124/
# 18                   https://habr.com/ru/news/763620/
# 4                    https://habr.com/ru/news/761862/
# 36                   https://habr.com/ru/news/756266/
# 15                   https://habr.com/ru/news/741664/
# 20  https://habr.com/ru/companies/otus/articles/73...
# 9    https://habr.com/ru/companies/yadro/news/723806/
# 13               https://habr.com/ru/articles/719692/
# 37                   https://habr.com/ru/news/712684/
# 1   https://habr.com/ru/companies/factory5/article...
# 31                   https://habr.com/ru/news/695298/
# 28  https://habr.com/ru/companies/factory5/news/69...
# 39  https://habr.com/ru/companies/factory5/news/68...
# 11  https://habr.com/ru/companies/yandex_praktikum...
# 33                   https://habr.com/ru/news/654707/
# 16   https://habr.com/ru/companies/slurm/news/646825/
# 12   https://habr.com/ru/companies/slurm/news/645485/
# 35   https://habr.com/ru/companies/slurm/news/595093/
# 3   https://habr.com/ru/companies/epam_systems/new...
# 19  https://habr.com/ru/companies/raiffeisenbank/n...
# 25                   https://habr.com/ru/news/531402/
# 10                   https://habr.com/ru/news/498364/
# 5   https://habr.com/ru/companies/yandex/news/497766/
# 30               https://habr.com/ru/articles/490518/
# 8   https://habr.com/ru/companies/yandex/articles/...
# 26  https://habr.com/ru/companies/beeline/articles...
# 23  https://habr.com/ru/companies/io/articles/264125/
# 0   https://habr.com/ru/companies/yandex/articles/...
# 7   https://habr.com/ru/companies/yandex/articles/...
# 27  https://habr.com/ru/companies/yandex/articles/...
